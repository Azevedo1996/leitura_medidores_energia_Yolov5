# %% [markdown]
# # YOLOv5

# %%
# !git clone https://github.com/ultralytics/yolov5;
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16094, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16094 (delta 0), reused 4 (delta 0), pack-reused 16089
# Receiving objects: 100% (16094/16094), 14.81 MiB | 15.27 MiB/s, done.
# Resolving deltas: 100% (11019/11019), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt;  # install
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %% [markdown]
# # TRAINING MODEL

# %% [markdown]
# YOLOV5S

# %%
# !python train.py  --batch 5 --epochs 50 --data coco128.yaml --weights yolov5s.pt
# Out:
# 2023-12-12 02:10:47.467221: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-12 02:10:47.467278: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-12 02:10:47.467319: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cp -r /content/yolov5/runs/train/exp5 /content/drive/MyDrive/leitura_medidores/yolov5s_5_50

# %% [markdown]
# YOLOV5M

# %%
# !python train.py  --batch 5 --epochs 50 --data coco128.yaml --weights yolov5m.pt
# Out:
# 2023-12-15 00:32:08.363810: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-15 00:32:08.363869: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-15 00:32:08.365759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cp -r /content/yolov5/runs/train/exp2 /content/drive/MyDrive/leitura_medidores/yolov5m_5_50

# %% [markdown]
# YOLOV5L

# %%
# !python train.py  --batch 5 --epochs 50 --data coco128.yaml --weights yolov5l.pt
# Out:
# 2023-12-15 10:54:27.357630: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-15 10:54:27.357709: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-15 10:54:27.359465: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cp -r /content/yolov5/runs/train/exp2 /content/drive/MyDrive/leitura_medidores/yolovl_5_50
